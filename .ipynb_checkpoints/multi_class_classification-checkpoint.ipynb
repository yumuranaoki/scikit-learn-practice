# %%
import mglearn
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import numpy as np
from sklearn.svm import LinearSVC
# Out:
# /Users/yumuranaoki/.pyenv/versions/3.6.3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
X, y = make_blobs(random_state=42)
mglearn.discrete_scatter(X[:,0], X[:, 1], y)
# Out:
# [<matplotlib.lines.Line2D at 0x1105b6438>,
#  <matplotlib.lines.Line2D at 0x110706278>,
#  <matplotlib.lines.Line2D at 0x1105a5cc0>]

# %%
linear_svc = LinearSVC().fit(X, y)

# %%
mglearn.discrete_scatter(X[:,0], X[:,1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in zip(linear_svc.coef_, linear_svc.intercept_, ['b', 'g', 'r']):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
