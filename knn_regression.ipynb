# %%
import mglearn
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
# Out:
# /Users/yumuranaoki/.pyenv/versions/3.6.3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %%
X, y = mglearn.datasets.make_wave(n_samples=40)
print("X: {}\ny: {}".format(X, y))
# Out:
# X: [[-0.75275929]
#  [ 2.70428584]
#  [ 1.39196365]
#  [ 0.59195091]
#  [-2.06388816]
#  [-2.06403288]
#  [-2.65149833]
#  [ 2.19705687]
#  [ 0.60669007]
#  [ 1.24843547]
#  [-2.87649303]
#  [ 2.81945911]
#  [ 1.99465584]
#  [-1.72596534]
#  [-1.9090502 ]
#  [-1.89957294]
#  [-1.17454654]
#  [ 0.14853859]
#  [-0.40832989]
#  [-1.25262516]
#  [ 0.67111737]
#  [-2.16303684]
#  [-1.24713211]
#  [-0.80182894]
#  [-0.26358009]
#  [ 1.71105577]
#  [-1.80195731]
#  [ 0.08540663]
#  [ 0.55448741]
#  [-2.72129752]
#  [ 0.64526911]
#  [-1.97685526]
#  [-2.60969044]
#  [ 2.69331322]
#  [ 2.7937922 ]
#  [ 1.85038409]
#  [-1.17231738]
#  [-2.41396732]
#  [ 1.10539816]
#  [-0.35908504]]
# y: [-0.44822073  0.33122576  0.77932073  0.03497884 -1.38773632 -2.47196233
#  -1.52730805  1.49417157  1.00032374  0.22956153 -1.05979555  0.7789638
#   0.75418806 -1.51369739 -1.67303415 -0.90496988  0.08448544 -0.52734666
#  -0.54114599 -0.3409073   0.21778193 -1.12469096  0.37299129  0.09756349
#  -0.98618122  0.96695428 -1.13455014  0.69798591  0.43655826 -0.95652133
#   0.03527881 -2.08581717 -0.47411033  1.53708251  0.86893293  1.87664889
#   0.0945257  -1.41502356  0.25438895  0.09398858]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
print("X_train: {}\nX_test: {}\ny_train: {}\ny_test: {}".format(X_train, X_test,  y_train, y_test))
# Out:
# X_train: [[-0.40832989]
#  [ 2.19705687]
#  [ 2.70428584]
#  [-1.17454654]
#  [-2.41396732]
#  [ 2.69331322]
#  [-1.80195731]
#  [-1.17231738]
#  [-2.06403288]
#  [ 1.71105577]
#  [-2.16303684]
#  [ 0.60669007]
#  [ 0.08540663]
#  [-1.25262516]
#  [ 2.81945911]
#  [ 1.10539816]
#  [-0.26358009]
#  [-0.75275929]
#  [-2.65149833]
#  [-2.87649303]
#  [-1.89957294]
#  [-1.24713211]
#  [ 0.64526911]
#  [ 0.14853859]
#  [-2.72129752]
#  [ 0.59195091]
#  [ 0.67111737]
#  [ 0.55448741]
#  [ 2.7937922 ]
#  [ 1.85038409]]
# X_test: [[ 1.39196365]
#  [ 1.99465584]
#  [ 1.24843547]
#  [-1.9090502 ]
#  [-2.60969044]
#  [-2.06388816]
#  [-0.35908504]
#  [-0.80182894]
#  [-1.97685526]
#  [-1.72596534]]
# y_train: [-0.54114599  1.49417157  0.33122576  0.08448544 -1.41502356  1.53708251
#  -1.13455014  0.0945257  -2.47196233  0.96695428 -1.12469096  1.00032374
#   0.69798591 -0.3409073   0.7789638   0.25438895 -0.98618122 -0.44822073
#  -1.52730805 -1.05979555 -0.90496988  0.37299129  0.03527881 -0.52734666
#  -0.95652133  0.03497884  0.21778193  0.43655826  0.86893293  1.87664889]
# y_test: [ 0.77932073  0.75418806  0.22956153 -1.67303415 -0.47411033 -1.38773632
#   0.09398858  0.09756349 -2.08581717 -1.51369739]

# %%
reg = KNeighborsRegressor(n_neighbors=3)
reg.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#           weights='uniform')

# %%
print("prediction score R^2: {}".format(reg.score(X_test, y_test)))
# Out:
# prediction score R^2: 0.7766554578848587

# %%
import numpy as np

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,4))
line = np.linspace(-3, 3, 1000).reshape(-1,1)
for n_neighbors, ax in zip([1,3,9], axes):
    reg = KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(X_train, y_train)
    ax.plot(line, reg.predict(line))
    ax.plot(X_train, y_train, '^')
    ax.plot(X_test, y_test, 'v')
